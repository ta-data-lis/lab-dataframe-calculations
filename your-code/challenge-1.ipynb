# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **Pokemon**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](../images/pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# #### Import all required libraries.

# %%
# import libraries

import numpy as np
import pandas as pd

# %% [markdown]
# #### Import data set.
#
# Read the dataset `pokemon.csv` into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import dataset

pokemon = pd.read_csv('/Users/GiadaSartori/Documents/IRONHACK/Lab/Week2/lab-dataframe-calculations/your-code/Pokemon.csv')
display(pokemon)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# #### Print first 10 rows of `pokemon`.

# %%
# your code here

pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# #### Obtain the distinct values across `Type 1` and `Type 2`.
#
# Exctract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
# your code here

#Obtain the distinct values of Type 1

#print(type(pokemon['Type 1'])) --> Type 1 is a series
#print(type(pokemon['Type 2'])) --> Type 2 is a series

pokemon_t1 = pokemon['Type 1'].unique()
pokemon_t1
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
#Obtain the distinct values of Type 1

pokemon_t2 = pokemon['Type 2'].unique()
pokemon_t2
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
#Create an array containing the distinct values across both fields.

p_unique_values = set(pokemon_t1) | set(pokemon_t2)
p_unique_values
# Out:
# {'Bug',
#  'Dark',
#  'Dragon',
#  'Electric',
#  'Fairy',
#  'Fighting',
#  'Fire',
#  'Flying',
#  'Ghost',
#  'Grass',
#  'Ground',
#  'Ice',
#  'Normal',
#  'Poison',
#  'Psychic',
#  'Rock',
#  'Steel',
#  'Water',
#  nan}

# %%
pokemon_values = pokemon[["Type 1", "Type 2"]].values.ravel()
unique_values = pd.unique(pokemon_values)
print(unique_values)
# Out:
# ['Grass' 'Poison' 'Fire' nan 'Flying' 'Dragon' 'Water' 'Bug' 'Normal'
#  'Electric' 'Ground' 'Fairy' 'Fighting' 'Psychic' 'Rock' 'Steel' 'Ice'
#  'Ghost' 'Dark']

# %% [markdown]
# #### Cleanup `Name` that contain "Mega".
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
# your code here

#Premise: Localize where the word 'Mega'is in the column Name, in order to retrive from the dataframe pokemon, which values or strings contain the word 'Mega'

pokemon.loc[pokemon['Name'].str.contains('Mega', case=False)]
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 3      3      VenusaurMega Venusaur     Grass    Poison    625   80     100
# 7      6  CharizardMega Charizard X      Fire    Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying    634   78     104
# 12     9    BlastoiseMega Blastoise     Water       NaN    630   79     103
# 19    15      BeedrillMega Beedrill       Bug    Poison    495   65     150
# 23    18        PidgeotMega Pidgeot    Normal    Flying    579   83      80
# 71    65      AlakazamMega Alakazam   Psychic       NaN    590   55      50
# 87    80        SlowbroMega Slowbro     Water   Psychic    590   95      75
# 102   94          GengarMega Gengar     Ghost    Poison    600   60      65
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN    590  105     125
# 137  127          PinsirMega Pinsir       Bug    Flying    600   65     155
# ...

# %%
#1: We understand that 'Mega' is a substring of the strings "VenusaurMega Venusaur" and "CharizardMega Charizard X", which appear in the column Name from the dataframe
# pokemon. We apply the find() specifically to both our strings to understand from which position/index our substring Mega starts. 

## Case for VenusaurMega Venusaur

name = 'VenusaurMega Venusaur' #string
mega = 'Mega' #substring of string 'mega'

print(name.find(mega))

start_index_of_mega = name.find(mega)

new_name = name[start_index_of_mega:]
new_name
# Out:
# 8
# 'Mega Venusaur'

# %%
## Case for CharizardMega Charizard X

name = 'CharizardMega Charizard X' #string
mega = 'Mega' #substring of string 'mega'

print(name.find(mega))

start_index_of_mega = name.find(mega)

new_name = name[start_index_of_mega:]
new_name
# Out:
# 9
# 'Mega Charizard X'

# %%
#2: We realize that in above cases, our variable or substring mega starts in position 8 for Mega Venusaur whereas in position 9 for string CharizardMega Charizard X. 
# We then create a generic function to clean the names/strings in scope and return the cleaned_name in case 'mega', as a substring, is found in the string. 

mega = 'Mega' #substring of whatever string we find in column Name

def clean_name(name):
    if 'Mega'in name:
        start_index_of_mega = name.find(mega)
        cleaned_name = name[start_index_of_mega:]    
        return cleaned_name
    else:
        return name

# %%
#3. Then we apply our generic function - apply(clean_name) - to the column 'Name'of our dataframe pokemon, and generate a new column called 'clean_name' where
#the cleaned names will be rendered. 

pokemon['clean_name'] = pokemon['Name'].apply(clean_name)
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# test transformed data
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary        clean_name
# 0       65       65     45           1      False         Bulbasaur
# ...

# %% [markdown]
# #### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`.
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
# your code here

pokemon['A/D Ratio'] = pokemon['Attack']/pokemon['Defense']

pokemon[['Attack', 'Defense', 'A/D Ratio']].head(30)
# Out:
#     Attack  Defense  A/D Ratio
# 0       49       49   1.000000
# 1       62       63   0.984127
# 2       82       83   0.987952
# 3      100      123   0.813008
# 4       52       43   1.209302
# 5       64       58   1.103448
# 6       84       78   1.076923
# 7      130      111   1.171171
# 8      104       78   1.333333
# 9       48       65   0.738462
# 10      63       80   0.787500
# 11      83      100   0.830000
# 12     103      120   0.858333
# 13      30       35   0.857143
# 14      20       55   0.363636
# 15      45       50   0.900000
# 16      35       30   1.166667
# 17      25       50   0.500000
# 18      90       40   2.250000
# 19     150       40   3.750000
# 20      45       40   1.125000
# 21      60       55   1.090909
# 22      80       75   1.066667
# 23      80       80   1.000000
# 24      56       35   1.600000
# 25      81       60   1.350000
# 26      60       30   2.000000
# 27      90       65   1.384615
# 28      60       44   1.363636
# ...

# %%
#At this point, the column A/D Ration is added as the last column of tha dataframe pokemon

pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary        clean_name  A/D Ratio
# ...

# %% [markdown]
# #### Identify the pokemon with the highest `A/D Ratio`.

# %%
#Add A/D Ratio to the dataframe pokemon

pokemon[['Attack', 'Defense', 'A/D Ratio']].head(30)
# Out:
#     Attack  Defense  A/D Ratio
# 0       49       49   1.000000
# 1       62       63   0.984127
# 2       82       83   0.987952
# 3      100      123   0.813008
# 4       52       43   1.209302
# 5       64       58   1.103448
# 6       84       78   1.076923
# 7      130      111   1.171171
# 8      104       78   1.333333
# 9       48       65   0.738462
# 10      63       80   0.787500
# 11      83      100   0.830000
# 12     103      120   0.858333
# 13      30       35   0.857143
# 14      20       55   0.363636
# 15      45       50   0.900000
# 16      35       30   1.166667
# 17      25       50   0.500000
# 18      90       40   2.250000
# 19     150       40   3.750000
# 20      45       40   1.125000
# 21      60       55   1.090909
# 22      80       75   1.066667
# 23      80       80   1.000000
# 24      56       35   1.600000
# 25      81       60   1.350000
# 26      60       30   2.000000
# 27      90       65   1.384615
# 28      60       44   1.363636
# ...

# %%
# your code here

#1. We retrieve what is the highest A/D Ratio

#Option 1
max_value = max(pokemon['A/D Ratio'])
max_value


#Option 2
pokemon['A/D Ratio'].max()
# Out:
# 9.0

# %%
#2. We want to localize the position of the pokemon with the highest A/D Ratio: 
# - Use df[column_name] to access a specific column from a DataFrame. 
# - Call column.idxmax() to return the index of the maximum value from the previous result column.

column = pokemon['A/D Ratio']
max_index = column.idxmax()
print(max_index)
# Out:
# 429

# %%
#3. We want to know which pokemon is in position 429

condition = pokemon['A/D Ratio'] == 9.0

pokemon[condition].head(1)
# Out:
#        #                Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic    NaN    600  50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary          clean_name  \
# 429      180       20    150           3       True  DeoxysAttack Forme
#
#      A/D Ratio
# 429        9.0

# %% [markdown]
# #### Identify the pokemon with the lowest A/D Ratio.

# %%
# your code here

#Option 1
min_value = min(pokemon['A/D Ratio'])
min_value

#Option 2
pokemon['A/D Ratio'].min()
# Out:
# 0.043478260869565216

# %%
#2. We want to localize the position of the pokemon with the lowest A/D Ratio: 
# - Use df[column_name] to access a specific column from a DataFrame. 
# - Call column.idmin() to return the index of the minimum value from the previous result column.

column = pokemon['A/D Ratio']
min_index = column.idxmin()
print(min_index)
# Out:
# 230

# %%
#3. We want to know which pokemon is in position 230

condition = pokemon['A/D Ratio'] == 0.043478260869565216

pokemon[condition].head(1)
# Out:
#        #     Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213  Shuckle    Bug   Rock    505  20      10      230       10      230
#
#      Speed  Generation  Legendary clean_name  A/D Ratio
# 230      5           2      False    Shuckle   0.043478

# %%
##Other solition, which is more efficient, and consists of defining a condition to extrapolate the details of the pokemon with the highest A/D Ratio.

##1. Max value

condition = pokemon['A/D Ratio'].max()

pokemon[pokemon['A/D Ratio'] == condition]
# Out:
#        #                Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic    NaN    600  50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary          clean_name  \
# 429      180       20    150           3       True  DeoxysAttack Forme
#
#      A/D Ratio
# 429        9.0

# %%
##2. Min value

condition = pokemon['A/D Ratio'].min()

pokemon[pokemon['A/D Ratio'] == condition]
# Out:
#        #     Name Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213  Shuckle    Bug   Rock    505  20      10      230       10      230
#
#      Speed  Generation  Legendary clean_name  A/D Ratio
# 230      5           2      False    Shuckle   0.043478

# %% [markdown]
# #### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
#1. Replace the NaN values for the entire pokemon dataframe, and reassign it again to the dataframe pokemon because .fillna() is not an inplace method

pokemon = pokemon.fillna(' ')

#We can also replace the NaN values only for column Type 2 --> pokemon['Type 2'] = pokemon['Type 2'].fillna(' ')

# %%
# your code here

#1. Replace the NaN values of Type 1

#pokemon['Type 1'] = pokemon['Type 1'].fillna(' ')

# %%
#1. Replace the NaN values of Type 2

#pokemon['Type 2'] = pokemon['Type 2'].fillna(' ')

# %%
#2. We sum two columns in a our pandas DataFrame and add the entries in each row to each other.

pokemon['Combo Type'] = pokemon['Type 1'] + ' ' + pokemon['Type 2']

# %%
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire            309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# #### Identify the pokemon whose `A/D Ratio` are among the top 5.

# %%
# your code here

#We know that the highest A/D ratio is 9.0, hence we set is a condition, and we look in the entire dataframe which are the pokemon with an A/D ratio equals to 9.0,
#then reduce the results to top 5

pokemon_top5 = pokemon[pokemon['A/D Ratio'] == pokemon['A/D Ratio'].max()].head(5)
pokemon_top5
# Out:
#        #                Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic           600  50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary          clean_name  \
# 429      180       20    150           3       True  DeoxysAttack Forme
#
#      A/D Ratio Combo Type
# 429        9.0  Psychic

# %% [markdown]
# #### For the 5 pokemon printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemon with the highest `A/D Ratio`.

# %%
# your code here

ls_pokemon = list(pokemon_top5['Combo Type'].unique())
ls_pokemon
# Out:
# ['Psychic  ']

# %% [markdown]
# #### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.
#
# Your output should look like below:
#
# ![Aggregate](../images/aggregated-mean.png)

# %%
pokemon['A/D Ratio']
# Out:
# 0      1.000000
# 1      0.984127
# 2      0.987952
# 3      0.813008
# 4      1.209302
#          ...
# 795    0.666667
# 796    1.454545
# 797    1.833333
# 798    2.666667
# 799    0.916667
# Name: A/D Ratio, Length: 800, dtype: float64

# %%
# your code here

pokemon.mean()
# Out:
# /var/folders/vy/72w35wd12ms4_h7n214795k40000gn/T/ipykernel_65695/3080266294.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pokemon.mean()
# #             362.813750
# Total         435.102500
# HP             69.258750
# Attack         79.001250
# Defense        73.842500
# Sp. Atk        72.820000
# Sp. Def        71.902500
# Speed          68.277500
# Generation      3.323750
# Legendary       0.081250
# A/D Ratio       1.164547
# dtype: float64
